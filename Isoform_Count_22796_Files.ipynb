# %%
#counting the number of isoforms in one file to double check formatting of isoforms

# %%
import pandas as pd
import re

# read in the unmerged csv1 dataframe
df = pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/0.01_Filter_proteinGroups_savitski_no_remap_8192.csv')

# extract the names and count of isoforms
isoforms = []
for protein_id in df['Protein Uniprot']:
    matches = re.findall(r'(\w+-\d+)', protein_id)
    if matches:
        isoforms.extend(matches)
        
isoform_count = len(isoforms)
unique_isoforms = set(isoforms)

print(f'Total number of isoforms: {isoform_count}')
print(f'Unique isoforms: {unique_isoforms}')
# Out:
# Total number of isoforms: 1708
# ...

# %%
#investigating the variants of the isoforms in one random file.

# %%
import pandas as pd
import re

# read in the unmerged csv1 dataframe
df = pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/0.01_Filter_proteinGroups_savitski_no_remap_8192.csv')

# extract the names and count of isoforms
isoform_counts = {}
for protein_id in df['Protein Uniprot']:
    matches = re.findall(r'(\w+)-(\d+)', protein_id)
    if matches:
        protein_name = matches[0][0]
        if protein_name not in isoform_counts:
            isoform_counts[protein_name] = 1
        else:
            isoform_counts[protein_name] += 1
        
print('Number of isoforms for each protein:')
for protein_name, count in isoform_counts.items():
    print(f'{protein_name}: {count}')
# Out:
# Number of isoforms for each protein:
# P48059: 2
# Q14194: 1
# O94925: 1
# P14618: 1
# P60660: 1
# Q01105: 2
# Q00325: 1
# P14314: 1
# Q8IY67: 1
# P46976: 1
# Q96G97: 1
# Q9Y4D8: 1
# O75369: 1
# P30044: 2
# P02545: 2
# Q7L2E3: 1
# Q9UHC6: 1
# Q96C92: 1
# Q12923: 1
# P78509: 1
# Q96ME1: 1
# Q5VWP3: 1
# P63092: 2
# Q9BQ52: 1
# Q13330: 1
# O15027: 2
# P56270: 2
# Q9BY32: 1
# Q15599: 2
# Q9BZ29: 1
# Q00610: 1
# Q6EEV4: 1
# O15294: 2
# P31942: 2
# Q03001: 4
# Q93050: 1
# Q07866: 5
# Q14C86: 1
# Q16563: 1
# Q969S9: 1
# Q5T6S3: 1
# Q96HC4: 2
# P08195: 3
# Q00653: 1
# Q13033: 1
# O75674: 1
# Q32MZ4: 2
# Q96A29: 1
# Q8IUI8: 1
# Q86X76: 2
# Q9UM54: 1
# P81605: 1
# P51114: 1
# Q8WWW0: 1
# Q14697: 1
# Q99490: 1
# Q96NM4: 1
# Q92614: 1
# P49589: 2
# O95785: 1
# Q9UJF2: 1
# P54886: 1
# P27216: 1
# P50542: 2
# Q96PQ7: 1
# O75781: 1
# Q8IZE3: 1
# Q9NXR1: 1
# Q92879: 1
# Q9BRX8: 1
# P29692: 3
# P48067: 1
# P21333: 1
# Q5VU43: 1
# Q9P206: 1
# P48730: 1
# A0FGR8: 2
# O95633: 1
# P55209: 2
# P50053: 1
# ...

# %%
import pandas as pd
import re

# read in the unmerged csv1 dataframe
df = pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/0.01_Filter_proteinGroups_savitski_no_remap_8192.csv')

# extract the names and count of isoforms
isoform_counts = {}
for protein_id in df['Protein Uniprot']:
    matches = re.findall(r'(\w+)-(\d+)', protein_id)
    if matches:
        protein_name = matches[0][0]
        if protein_name not in isoform_counts:
            isoform_counts[protein_name] = 1
        else:
            isoform_counts[protein_name] += 1

# create a new dataframe with the protein Uniprot ID and number of isoforms
output_df = pd.DataFrame({'Protein Uniprot': list(isoform_counts.keys()), 'Number of Isoforms': list(isoform_counts.values())})

# save the dataframe to a new CSV file
output_df.to_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/output_file.csv', index=False)

print('Number of isoforms for each protein:')
for protein_name, count in isoform_counts.items():
    print(f'{protein_name}: {count}')
# Out:
# Number of isoforms for each protein:
# P48059: 2
# Q14194: 1
# O94925: 1
# P14618: 1
# P60660: 1
# Q01105: 2
# Q00325: 1
# P14314: 1
# Q8IY67: 1
# P46976: 1
# Q96G97: 1
# Q9Y4D8: 1
# O75369: 1
# P30044: 2
# P02545: 2
# Q7L2E3: 1
# Q9UHC6: 1
# Q96C92: 1
# Q12923: 1
# P78509: 1
# Q96ME1: 1
# Q5VWP3: 1
# P63092: 2
# Q9BQ52: 1
# Q13330: 1
# O15027: 2
# P56270: 2
# Q9BY32: 1
# Q15599: 2
# Q9BZ29: 1
# Q00610: 1
# Q6EEV4: 1
# O15294: 2
# P31942: 2
# Q03001: 4
# Q93050: 1
# Q07866: 5
# Q14C86: 1
# Q16563: 1
# Q969S9: 1
# Q5T6S3: 1
# Q96HC4: 2
# P08195: 3
# Q00653: 1
# Q13033: 1
# O75674: 1
# Q32MZ4: 2
# Q96A29: 1
# Q8IUI8: 1
# Q86X76: 2
# Q9UM54: 1
# P81605: 1
# P51114: 1
# Q8WWW0: 1
# Q14697: 1
# Q99490: 1
# Q96NM4: 1
# Q92614: 1
# P49589: 2
# O95785: 1
# Q9UJF2: 1
# P54886: 1
# P27216: 1
# P50542: 2
# Q96PQ7: 1
# O75781: 1
# Q8IZE3: 1
# Q9NXR1: 1
# Q92879: 1
# Q9BRX8: 1
# P29692: 3
# P48067: 1
# P21333: 1
# Q5VU43: 1
# Q9P206: 1
# P48730: 1
# A0FGR8: 2
# O95633: 1
# P55209: 2
# P50053: 1
# ...

# %%
#checking if csv file contains the protein as well as ISOFORM.

# %%
df=pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/output_file.csv')
print(df)
# Out:
#      Protein Uniprot  Number of Isoforms
# 0             P48059                   2
# 1             Q14194                   1
# 2             O94925                   1
# 3             P14618                   1
# 4             P60660                   1
# ...              ...                 ...
# 1503          Q8WWR9                   1
# 1504          Q9UIL1                   1
# 1505          Q12802                   1
# 1506          Q96GQ5                   1
# 1507          Q9NSK0                   1
#
# [1508 rows x 2 columns]

# %%
import pandas as pd

# Read in both CSV files
df1 = pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/output_file.csv')
df2 = pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/0.01_Filter_proteinGroups_savitski_no_remap_8192.csv')

# Create a set of unique Protein Uniprot IDs from df2
uniprot_ids = set(df2['Protein Uniprot'])

# Check if each Protein Uniprot ID in df1 is present in the set of uniprot_ids
for protein_id in df1['Protein Uniprot']:
    if protein_id in uniprot_ids:
        print(f"{protein_id} is present in csv2")
    else:
        print(f"{protein_id} is not present in csv2")
# Out:
# P48059 is present in csv2
# Q14194 is present in csv2
# O94925 is present in csv2
# P14618 is not present in csv2
# P60660 is present in csv2
# Q01105 is present in csv2
# Q00325 is present in csv2
# P14314 is not present in csv2
# Q8IY67 is present in csv2
# P46976 is present in csv2
# Q96G97 is not present in csv2
# Q9Y4D8 is not present in csv2
# O75369 is not present in csv2
# P30044 is not present in csv2
# P02545 is not present in csv2
# Q7L2E3 is present in csv2
# Q9UHC6 is present in csv2
# Q96C92 is not present in csv2
# Q12923 is not present in csv2
# P78509 is not present in csv2
# Q96ME1 is not present in csv2
# Q5VWP3 is not present in csv2
# P63092 is not present in csv2
# Q9BQ52 is not present in csv2
# Q13330 is not present in csv2
# O15027 is not present in csv2
# P56270 is not present in csv2
# Q9BY32 is present in csv2
# Q15599 is not present in csv2
# Q9BZ29 is not present in csv2
# Q00610 is not present in csv2
# Q6EEV4 is not present in csv2
# ...

# %%
import pandas as pd
import re

# read in the unmerged csv1 dataframe
df = pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/0.01_Filter_proteinGroups_savitski_no_remap_8192.csv')

# extract the names and count of isoforms
isoform_counts = {}
isoform_variants = {}
for protein_id in df['Protein Uniprot']:
    matches = re.findall(r'(\w+)-(\d+)', protein_id)
    if matches:
        protein_name = matches[0][0]
        isoform_number = matches[0][1]
        if protein_name not in isoform_counts:
            isoform_counts[protein_name] = 1
            isoform_variants[protein_name] = [isoform_number]
        else:
            isoform_counts[protein_name] += 1
            isoform_variants[protein_name].append(isoform_number)
        
print('Number of isoforms and their variants for each protein:')
for protein_name, count in isoform_counts.items():
    print(f'{protein_name}: {count} isoform(s) ({", ".join(isoform_variants[protein_name])})')

# %%
#finding the isoform length and mass.

# %%
import pandas as pd
import re

# read in the unmerged csv1 dataframe
df = pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/0.01_Filter_proteinGroups_picked_protein_group_no_remap_22796.csv')

# extract the names and count of isoforms
isoforms = []
for protein_id in df['Protein Uniprot']:
    matches = re.findall(r'(\w+-\d+)', protein_id)
    if matches:
        isoforms.extend(matches)

isoform_count = len(isoforms)
unique_isoforms = set(isoforms)

print(f'Total number of isoforms: {isoform_count}')
print(f'Unique isoforms: {unique_isoforms}')

# create a new DataFrame with the isoform information
isoform_df = pd.DataFrame(isoforms, columns=['Isoform'])

# save the DataFrame to a new CSV file
isoform_df.to_csv('isoforms_picked_protein_group_no_remap_22796.csv', index=False)
# Out:
# Total number of isoforms: 2327
# ...

# %%
df=pd.read_csv('isoforms_picked_protein_group_no_remap_22796.csv')
print(df)
# Out:
#        Isoform
# 0     Q12906-7
# 1     Q68E01-2
# 2     P09651-2
# 3     Q00610-2
# 4     Q53GG5-2
# ...        ...
# 2322  Q13356-2
# 2323  Q8WU39-2
# 2324  O75679-2
# 2325  Q9NVV4-2
# 2326  Q9UPM6-5
#
# [2327 rows x 1 columns]

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
from time import sleep

def get_fasta_isoform(isoform_id):
    # define the UniProt API endpoint for the protein isoform
    url = f"https://www.uniprot.org/uniprot/{isoform_id}.fasta"

    # send a GET request to the UniProt API endpoint to retrieve the protein sequence
    response = requests.get(url)

    lines = response.text.split('\n')
    fasta_isoform = ''.join(lines[1:])

    return fasta_isoform

def get_protparams(uniprot_id):
    try:
        # Define the URL for the ProtParam tool
        url = "https://web.expasy.org/cgi-bin/protparam/protparam"

        # Define the payload for the GET request
        sequence = get_fasta_isoform(uniprot_id)
        payload = {"sequence": sequence}

        # Submit the GET request and get the response
        response = requests.post(url, data=payload)

        soup = BeautifulSoup(response.content, "html.parser")
        num_amino_acids_raw = soup.find(string="Number of amino acids:").next
        mol_weight_raw = soup.find(string="Molecular weight:").next

        num_amino_acids_raw = int(num_amino_acids_raw)
        mol_weight_raw = float(mol_weight_raw)

        return {'Uniprot ID': uniprot_id, 'Molecular Weight': mol_weight_raw, 'Number of amino acids': num_amino_acids_raw}
    except Exception as e:
        print(f"Error processing {uniprot_id}: {e}")
        return None

# Load the UniProt IDs from a CSV file
df = pd.read_csv('isoforms_picked_protein_group_no_remap_22796.csv')

# Use a ThreadPoolExecutor to run the tasks in parallel
with ThreadPoolExecutor() as executor:
    futures = []
    for uniprot_id in df['Isoform']:
        futures.append(executor.submit(get_protparams, uniprot_id))
        # sleep(1)  # sleep for 1 second

    # Collect the results from the futures
    results = []
    for future in futures:
        result = future.result()
        if result is not None:
            results.append(result)

# Convert the results to a DataFrame
result = pd.DataFrame(results)

# Save the result to a new CSV file
result.to_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/CSV_Files_No_Separation/SeparateProteinIDs_No_Separation_ProteinGroups.output/Uniprot_IDs_Isoforms_Raw_Files/Uniprot_Mass_test.csv', index=False)

# Print the resulting DataFrame
print(result)
# Out:
#      Uniprot ID  Molecular Weight  Number of amino acids
# 0      Q12906-7          95807.91                    898
# 1      Q68E01-2         118012.71                   1042
# 2      P09651-2          34196.20                    320
# 3      Q00610-2         187890.41                   1639
# 4      Q53GG5-2          34279.66                    316
# ...         ...               ...                    ...
# 2322   Q13356-2          59458.20                    527
# 2323   Q8WU39-2          13066.03                    123
# 2324   O75679-2          32171.09                    288
# 2325   Q9NVV4-2          78833.24                    712
# 2326   Q9UPM6-5          40159.84                    366
#
# [2327 rows x 3 columns]

# %%
df_ = pd.DataFrame(results)
# Out:
# Error processing Q8NF91-4: 'NoneType' object has no attribute 'next'

# %%
df_.loc[df_['Uniprot ID'] == 'Q8NF91-4']
# Out:
# Empty DataFrame
# Columns: [Uniprot ID, Molecular Weight, Number of amino acids]
# Index: []

# %%
get_protparams('Q8NF91-4')
# Out:
# Error processing Q8NF91-4: 'NoneType' object has no attribute 'next'
# Error processing Q5VST9-6: 'NoneType' object has no attribute 'next'
# Error processing P20929-3: 'NoneType' object has no attribute 'next'
# Error processing Q8WZ42-12: 'NoneType' object has no attribute 'next'
# Error processing Q8WZ42-2: 'NoneType' object has no attribute 'next'

# %%
Q8NF91-4: 'NoneType' object has no attribute 'next'
Error processing Q5VST9-6: 'NoneType' object has no attribute 'next'
Error processing P20929-3: 'NoneType' object has no attribute 'next'
Error processing Q8WZ42-12: 'NoneType' object has no attribute 'next'
Error processing Q8WZ42-2: 'NoneType' object has no att
