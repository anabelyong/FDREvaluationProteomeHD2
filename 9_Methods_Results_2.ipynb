# %%
import pandas as pd
df= pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/Modified_for_Plots_Microproteins.csv')
print(df)
# Out:
#                                             File Name     sp  nC  pI  sU  sR  \
# 0   0.01_Filter_proteinGroups_savitski_no_remap_25...   8371   0   5   0  10
# 1   0.01_Filter_proteinGroups_classic_no_grouping_...   7050   0   4   0   5
# 2   0.01_Filter_proteinGroups_classic_grouping_no_...   8036   0   1   0   4
# 3   0.01_Filter_proteinGroups_classic_grouping_no_...   7722   0   1   0   1
# 4   0.01_Filter_proteinGroups_classic_rescue_group...   7733   0   1   0   1
# ..                                                ...    ...  ..  ..  ..  ..
# 75  0.01_Filter_proteinGroups_classic_grouping_no_...   7353   0   1   0   2
# 76  0.01_Filter_proteinGroups_savitski_no_remap_20...  11215   1  15   0  16
# 77  0.01_Filter_proteinGroups_picked_protein_group...  11333   0  10   0   7
# 78  0.01_Filter_proteinGroups_classic_rescue_group...   7360   0   1   0   2
# 79  0.01_Filter_proteinGroups_savitski_no_remap_8.csv   4692   0   1   0   2
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# read the CSV file
df= pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/Results/Modified_for_Plots_Microproteins.csv')

grouped_df = df.groupby(['Method', 'Number of Raw Files']).mean().reset_index()

# pivot the table so that each protein type becomes a separate column
pivoted_df = grouped_df.pivot(index='Number of Raw Files', columns='Method')

# plot the line chart for each protein type
for col in ['pI', 'sU', 'sR', 'nC', 'sp']:
    pivoted_df[col].plot(kind='line', figsize=(10, 6), linewidth=2)
    plt.xlabel('Number of Raw Files')
    plt.ylabel(col)
    plt.title('Count of ' + col + ' at 1% FDR')
    plt.legend()
    plt.show()
# Out:
# /var/folders/bt/n98c3tq15s3d6866b0l_z_400000gn/T/ipykernel_12444/4281401197.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_df = df.groupby(['Method', 'Number of Raw Files']).mean().reset_index()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# read the CSV file
df= pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/Results/Modified_for_Plots_Microproteins.csv')

# specify the 3 methods you want to plot
methods_to_plot = ["classic_no_grouping_no_remap", "savitski_no_remap", "picked_protein_group_no_remap"]

# filter the dataframe to include only the specified methods
df_filtered = df[df["Method"].isin(methods_to_plot)]

grouped_df = df_filtered.groupby(['Method', 'Number of Raw Files']).mean().reset_index()

# pivot the table so that each protein type becomes a separate column
pivoted_df = grouped_df.pivot(index='Number of Raw Files', columns='Method')

# plot the line chart for each protein type
for col in ['pI', 'sU', 'sR', 'nC', 'sp']:
    pivoted_df[col].plot(kind='line', figsize=(10, 6), linewidth=2)
    plt.xlabel('Number of Raw Files')
    plt.ylabel(col)
    plt.title('Count of ' + col + ' at 1% FDR')
    plt.legend()
    plt.show()
# Out:
# /var/folders/bt/n98c3tq15s3d6866b0l_z_400000gn/T/ipykernel_12444/1839745286.py:13: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_df = df_filtered.groupby(['Method', 'Number of Raw Files']).mean().reset_index()

# %%
df= pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/SeparateIDs_proteinGroups_methods_files/proteinGroups_picked_subset_no_remap_anabel_22796.csv')
print(df)
# Out:
#         Q-value Protein Type       Protein Uniprot Protein Label
# 0      0.000095           sp                P35527    K1C9_HUMAN
# 1      0.000095           sp                P06702   S10A9_HUMAN
# 2      0.000095           sp                P55072    TERA_HUMAN
# 3      0.000095           sp                Q6UVK1   CSPG4_HUMAN
# 4      0.000095           sp                P08670    VIME_HUMAN
# ...         ...          ...                   ...           ...
# 48083  0.566296      REV__sR       single_ribo2313           NaN
# 48084  0.566296      REV__sR        single_ribo669           NaN
# 48085  0.566296           sp              Q9BUR5-2   MIC26_HUMAN
# 48086  0.566296           sp              O43766-3    LIAS_HUMAN
# 48087  0.566296           sR  single_ribo769_HUMAN           NaN
#
# [48088 rows x 4 columns]

# %%
#displaying the number of target proteins in each raw file

# %%
import pandas as pd
import glob
import os

# Create the output directory if it does not exist
output_dir = '/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter'
os.makedirs(output_dir, exist_ok=True)

# Replace '*.csv' with the pattern for your input files
for file_path in glob.glob('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/*.csv'):
    # Generate output file name with the prefix '0.01_Filter_' and suffix '.csv'
    output_file_name = '0.01_Filter_' + os.path.basename(file_path)
    output_file_path = os.path.join(output_dir, output_file_name)

    # Read input CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Filter for Q-value < 0.01
    df = df[df['Q-value'] < 0.01]

    # Split the column by '|', but only keep the first two splits if there are more than 2
    split_col = df['Protein IDs'].str.split('|', n=2, expand=True)

    # Rename the new columns
    split_col.columns = ['Protein Type', 'Protein Uniprot', 'Protein Label']

    # Concatenate the original DataFrame and the new columns
    new_df = pd.concat([df['Q-value'], split_col], axis=1)

    # Count the number of target proteins (without 'REV__' in Protein Label)
    num_targets = len(new_df[new_df['Protein Label'].str.startswith('REV__', na=False)==False])

    # Print the filename and number of target proteins
    print(f"{output_file_name}: {num_targets} target proteins")
# Out:
# 0.01_Filter_proteinGroups_picked_protein_group_no_remap_128.csv: 11462 target proteins
# 0.01_Filter_proteinGroups_classic_grouping_no_remap_16.csv: 8120 target proteins
# 0.01_Filter_proteinGroups_savitski_subset_no_remap_1.csv: 6396 target proteins
# 0.01_Filter_proteinGroups_classic_rescue_grouping_no_remap_8192.csv: 15938 target proteins
# 0.01_Filter_proteinGroups_picked_no_grouping_no_remap_16384.csv: 12565 target proteins
# 0.01_Filter_proteinGroups_picked_subset_no_remap_512.csv: 12970 target proteins
# 0.01_Filter_proteinGroups_picked_protein_group_no_remap_64.csv: 10871 target proteins
# 0.01_Filter_proteinGroups_classic_no_grouping_no_remap_512.csv: 9378 target proteins
# 0.01_Filter_proteinGroups_picked_no_grouping_no_remap_16.csv: 4973 target proteins
# 0.01_Filter_proteinGroups_picked_subset_no_remap_128.csv: 11355 target proteins
# 0.01_Filter_proteinGroups_picked_subset_no_remap_16.csv: 8195 target proteins
# ...

# %%
import pandas as pd
import glob
import os

# Create the output directory if it does not exist
output_dir = '/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter'
os.makedirs(output_dir, exist_ok=True)

# Replace '*.csv' with the pattern for your input files
for file_path in glob.glob('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/*.csv'):
    # Extract the method and number of raw files from the file name
    file_name = os.path.basename(file_path)
    method = file_name.split('proteinGroups_')[1].split('_16')[0]
    num_raw_files = file_name.split('_')[-1].split('.')[0]

    # Generate output file name with the prefix '0.01_Filter_' and suffix '.csv'
    output_file_name = '0.01_Filter_' + file_name
    output_file_path = os.path.join(output_dir, output_file_name)

    # Read input CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Filter for Q-value < 0.01
    df = df[df['Q-value'] < 0.01]

    # Split the column by '|', but only keep the first two splits if there are more than 2
    split_col = df['Protein IDs'].str.split('|', n=2, expand=True)

    # Rename the new columns
    split_col.columns = ['Protein Type', 'Protein Uniprot', 'Protein Label']

    # Concatenate the original DataFrame and the new columns
    new_df = pd.concat([df['Q-value'], split_col], axis=1)

    # Count the number of target proteins (without 'REV__' in Protein Label)
    num_targets = len(new_df[new_df['Protein Type'].str.startswith('REV__', na=False)==False])

    # Add the method, number of raw files, and number of target proteins as new columns to the DataFrame
    new_df['Method'] = method
    new_df['Num Raw Files'] = num_raw_files
    new_df['Num Target Proteins'] = num_targets

    # Write the new DataFrame to a separate CSV file
    new_df.to_csv(output_file_path, index=False)

    # Print the file name, method, number of raw files, and number of target proteins
    print(f"{output_file_name}: Method={method}, Num Raw Files={num_raw_files}, Num Target Proteins={num_targets}")
# Out:
# 0.01_Filter_proteinGroups_picked_protein_group_no_remap_128.csv: Method=picked_protein_group_no_remap_128.csv, Num Raw Files=128, Num Target Proteins=11350
# 0.01_Filter_proteinGroups_classic_grouping_no_remap_16.csv: Method=classic_grouping_no_remap, Num Raw Files=16, Num Target Proteins=8041
# 0.01_Filter_proteinGroups_savitski_subset_no_remap_1.csv: Method=savitski_subset_no_remap_1.csv, Num Raw Files=1, Num Target Proteins=6334
# 0.01_Filter_proteinGroups_classic_rescue_grouping_no_remap_8192.csv: Method=classic_rescue_grouping_no_remap_8192.csv, Num Raw Files=8192, Num Target Proteins=15782
# 0.01_Filter_proteinGroups_picked_no_grouping_no_remap_16384.csv: Method=picked_no_grouping_no_remap, Num Raw Files=16384, Num Target Proteins=12442
# 0.01_Filter_proteinGroups_picked_subset_no_remap_512.csv: Method=picked_subset_no_remap_512.csv, Num Raw Files=512, Num Target Proteins=12843
# ...

# %%
#filtered_data_9_methods to csv

# %%
import pandas as pd
import glob
import os

# Create an empty list to store the data
data = []

# Replace '*.csv' with the pattern for your input files
for file_path in glob.glob('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/*.csv'):
    # Extract the method and number of raw files from the file name
    file_name = os.path.basename(file_path)
    method = file_name.split('proteinGroups_')[1].split('.csv')[0]
    num_raw_files = method.split('_')[-1]
    method = method.split('_' + num_raw_files)[0]

    # Read input CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Filter for Q-value < 0.01
    df = df[df['Q-value'] < 0.01]

    # Split the column by '|', but only keep the first two splits if there are more than 2
    split_col = df['Protein IDs'].str.split('|', n=2, expand=True)

    # Rename the new columns
    split_col.columns = ['Protein Type', 'Protein Uniprot', 'Protein Label']

    # Concatenate the original DataFrame and the new columns
    new_df = pd.concat([df['Q-value'], split_col], axis=1)

    # Count the number of target proteins (without 'REV__' in Protein Label)
    num_targets = len(new_df[new_df['Protein Label'].str.startswith('REV__', na=False)==False])

    # Add the data to the list
    data.append([file_name, method, num_raw_files, num_targets])

# Create a DataFrame from the list of data
df = pd.DataFrame(data, columns=['File Name', 'Method', 'Num Raw Files', 'Num Target Proteins'])

# Write the DataFrame to a CSV file
df.to_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/filtered_data_9_methods.csv', index=False)

# %%
df=pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/filtered_data_9_methods.csv')
print(df)
# Out:
#                                              File Name  \
# 0    proteinGroups_picked_protein_group_no_remap_12...
# 1       proteinGroups_classic_grouping_no_remap_16.csv
# 2         proteinGroups_savitski_subset_no_remap_1.csv
# 3    proteinGroups_classic_rescue_grouping_no_remap...
# 4    proteinGroups_picked_no_grouping_no_remap_1638...
# ..                                                 ...
# 139   proteinGroups_classic_no_grouping_no_remap_1.csv
# 140     proteinGroups_classic_grouping_no_remap_32.csv
# 141  proteinGroups_classic_rescue_grouping_no_remap...
# 142  proteinGroups_savitski_rescued_subset_no_remap...
# 143     proteinGroups_savitski_subset_no_remap_128.csv
#
#                                Method  Num Raw Files  Num Target Proteins
# 0       picked_protein_group_no_remap            128                11462
# 1           classic_grouping_no_remap             16                 8120
# 2            savitski_subset_no_remap              1                 6396
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the filtered data CSV file
df = pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/filtered_data_9_methods.csv')

# Group the data by method
grouped = df.groupby('Method')

# Set up the plot
fig, ax = plt.subplots()

# Set up colors for each method
colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black','brown','pink']

# Loop through each group and plot the data
for i, (method, group) in enumerate(grouped):
    # Sort the group by the number of raw files
    group = group.sort_values('Num Raw Files')
    # Plot the data as a line
    ax.plot(group['Num Raw Files'], group['Num Target Proteins'], color=colors[i], label=method)

# Set up the legend and axis labels
ax.legend()
ax.set_xlabel('Number of Raw Files')
ax.set_ylabel('Number of Target Proteins')
ax.set_title('Target Proteins at 1% FDR against Number of Raw Files')

# Show the plot
plt.show()

# %%
#Different TDS strategies.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the filtered data CSV file
df = pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/filtered_data_9_methods.csv')

# Choose the methods you want to plot
methods_to_plot = ['classic_grouping_no_remap', 'classic_no_grouping_no_remap', 'classic_rescue_grouping_no_remap']

# Group the data by method
grouped = df.groupby('Method')

# Set up the plot
fig, ax = plt.subplots()

# Set up colors for each method
colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black','brown','pink']

# Loop through each group and plot the data for the selected methods
for i, method in enumerate(methods_to_plot):
    if method in grouped.groups:
        group = grouped.get_group(method).sort_values('Num Raw Files')
        ax.plot(group['Num Raw Files'], group['Num Target Proteins'], color=colors[i], label=method)

# Set up the legend and axis labels
ax.legend()
ax.set_xlabel('Number of Raw Files')
ax.set_ylabel('Number of Target Proteins')
ax.set_title('Target Proteins at 1% FDR- Classical FDR methods')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the filtered data CSV file
df = pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/filtered_data_9_methods.csv')

# Choose the methods you want to plot
methods_to_plot = ['savitski_no_remap', 'savitski_subset_no_remap', 'savitski_rescued_subset_no_remap']

# Group the data by method
grouped = df.groupby('Method')

# Set up the plot
fig, ax = plt.subplots()

# Set up colors for each method
colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black','brown','pink']

# Loop through each group and plot the data for the selected methods
for i, method in enumerate(methods_to_plot):
    if method in grouped.groups:
        group = grouped.get_group(method).sort_values('Num Raw Files')
        ax.plot(group['Num Raw Files'], group['Num Target Proteins'], color=colors[i], label=method)

# Set up the legend and axis labels
ax.legend()
ax.set_xlabel('Number of Raw Files')
ax.set_ylabel('Number of Target Proteins')
ax.set_title('Target Proteins at 1% FDR- Picked Protein FDR methods')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the filtered data CSV file
df = pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/filtered_data_9_methods.csv')

# Choose the methods you want to plot
methods_to_plot = ['picked_no_grouping_no_remap', 'picked_subset_no_remap', 'picked_protein_group_no_remap']

# Group the data by method
grouped = df.groupby('Method')

# Set up the plot
fig, ax = plt.subplots()

# Set up colors for each method
colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black','brown','pink']

# Loop through each group and plot the data for the selected methods
for i, method in enumerate(methods_to_plot):
    if method in grouped.groups:
        group = grouped.get_group(method).sort_values('Num Raw Files')
        ax.plot(group['Num Raw Files'], group['Num Target Proteins'], color=colors[i], label=method)

# Set up the legend and axis labels
ax.legend()
ax.set_xlabel('Number of Raw Files')
ax.set_ylabel('Number of Target Proteins')
ax.set_title('Target Proteins at 1% FDR- Picked Protein FDR methods')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the filtered data CSV file
df = pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/Results/filtered_data_9_methods.csv')

# Choose the methods you want to plot
methods_to_plot = ['classic_no_grouping_no_remap', 'savitski_no_remap', 'picked_protein_group_no_remap']

# Group the data by method
grouped = df.groupby('Method')

# Set up the plot
fig, ax = plt.subplots()

# Set up colors for each method
colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black','brown','pink']

# Loop through each group and plot the data for the selected methods
for i, method in enumerate(methods_to_plot):
    if method in grouped.groups:
        group = grouped.get_group(method).sort_values('Num Raw Files')
        ax.plot(group['Num Raw Files'], group['Num Target Proteins'], color=colors[i], label=method)

# Set up the legend and axis labels
ax.legend()
ax.set_xlabel('Number of Raw Files')
ax.set_ylabel('Number of Target Proteins')
ax.set_title('Target Proteins at 1% FDR')

# Show the plot
plt.show()

# %%
#Difference between approaches.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Read the filtered data CSV file
df = pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/proteinGroups_methods_files/0.01_Filter/Results/filtered_data_9_methods.csv')

# Choose the methods you want to plot
method1 = 'classic_no_grouping_no_remap'
method2 = 'savitski_no_remap'

# Filter the data for the selected methods
data1 = df[df['Method'] == method1].sort_values('Num Raw Files')
data2 = df[df['Method'] == method2].sort_values('Num Raw Files')

# Get the intersection of raw file names for the two methods
common_raw_files = np.intersect1d(data1['Num Raw Files'], data2['Num Raw Files'])

# Filter the data to only include the common raw files
data1 = data1[data1['Num Raw Files'].isin(common_raw_files)]
data2 = data2[data2['Num Raw Files'].isin(common_raw_files)]

# Get the number of target proteins for each method and raw file
num_target_proteins1 = data1['Num Target Proteins'].values
num_target_proteins2 = data2['Num Target Proteins'].values
num_raw_files = data1['Num Raw Files'].values

# Calculate the difference in number of target proteins
diff_target_proteins = num_target_proteins2 - num_target_proteins1

# Set up the plot
fig, ax = plt.subplots()

# Plot the data points as a scatter plot
ax.scatter(num_raw_files, diff_target_proteins, label=f'{method2} - {method1}', color='blue')

# Set up the legend and axis labels
ax.set_xlabel('Number of Raw Files')
ax.set_ylabel('# of Target Proteins picked - classic')
#ax.set_title(f'{method2} - {method1} Target Proteins at 1% FDR against Number of Raw Files')

# Show the plot
plt.show()
