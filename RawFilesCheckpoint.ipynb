# %% [markdown]
# # converting txt files for 100-1600 for data analysis

# %%
import csv

# Open input and output files
with open('Classic_no_grouping_no_remap_100Files.txt', 'r') as input_file, open('100Files.csv', 'w', newline='') as output_file:
    # Create a CSV writer object
    writer = csv.writer(output_file)

    # Iterate over each line in the input file
    for line in input_file:
        # Split the line into fields using the tab delimiter
        fields = line.strip().split('\t')

        # Write the fields to the CSV file
        writer.writerow(fields)

# %%
import csv
import glob

# Replace '*.txt' with the pattern for your input files
for file_path in glob.glob('*.txt'):
    # Generate output file name by replacing '.txt' with '.csv'
    output_file_path = file_path.replace('.txt', '.csv')

    with open(file_path, 'r') as input_file, open(output_file_path, 'w', newline='') as output_file:
        # Create a CSV writer object
        writer = csv.writer(output_file)
        
        # Iterate over each line in the input file
        for line in input_file:
            # Split the line into fields using the tab delimiter
            fields = line.strip().split('\t')

            # Write the fields to the CSV file
            writer.writerow(fields)

# %% [markdown]
# # Evaluating the converted CSV files

# %%
import pandas as pd
import glob

# Replace '*.csv' with the pattern for your input files
for file_path in glob.glob('*.csv'):
    # Generate output file name by prefixing 'Separate' to the input file name
    output_file_path = 'SeparateProteinIDs' + file_path

    # Read input CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Split the column by '|', but only keep the first two splits if there are more than 2
    split_col = df['Protein IDs'].str.split('|', n=2, expand=True)

    # Rename the new columns
    split_col.columns = ['Protein Type', 'Protein Uniprot', 'Protein Label']

    # Concatenate the original DataFrame and the new columns
    new_df = pd.concat([df['Q-value'], split_col], axis=1)

    # Write the new DataFrame to a separate CSV file
    new_df.to_csv(output_file_path, index=False)

# %%
#double checking the csv files which have separated protein types
df=pd.read_csv('SeparateProteinIDsClassic_no_grouping_no_remap_500Files.csv')
print(df)
# Out:
#         Q-value Protein Type Protein Uniprot Protein Label
# 0      0.000269           sp          P35579    MYH9_HUMAN
# 1      0.000269           sp          P04843    RPN1_HUMAN
# 2      0.000269           sp          O15372   EIF3H_HUMAN
# 3      0.000269           sp          Q99584   S10AD_HUMAN
# 4      0.000269           sp          P46778    RL21_HUMAN
# ...         ...          ...             ...           ...
# 17814  0.715317           sp        Q9BUR5-2   MIC26_HUMAN
# 17815  0.715413      REV__sp          Q9BZA8   PC11Y_HUMAN
# 17816  0.715510      REV__sp          Q9H1Z4   WDR13_HUMAN
# 17817  0.715537      REV__sp        Q6ISS4-2   LAIR2_HUMAN
# 17818  0.715537           sp        Q06330-3     SUH_HUMAN
#
# [17819 rows x 4 columns]

# %%
#double checking the csv files which have separated protein types
df=pd.read_csv('SeparateProteinIDsClassic_no_grouping_no_remap_5000Files.csv')
print(df)
# Out:
#         Q-value Protein Type Protein Uniprot Protein Label
# 0      0.000353           sp          P35579    MYH9_HUMAN
# 1      0.000353           sp          Q15365   PCBP1_HUMAN
# 2      0.000353           sp          P09669   COX6C_HUMAN
# 3      0.000353           sp          Q12768   WASC5_HUMAN
# 4      0.000353           sp          O75477   ERLN1_HUMAN
# ...         ...          ...             ...           ...
# 47899  0.989616      REV__sp        A5D8T8-2   CL18A_HUMAN
# 47900  0.989617      REV__sp        Q9HAC7-2   SUCHY_HUMAN
# 47901  0.989617      REV__sp        Q8N884-2    CGAS_HUMAN
# 47902  0.989617           sp        Q06330-3     SUH_HUMAN
# 47903  0.989617           sp        Q01433-3   AMPD2_HUMAN
#
# [47904 rows x 4 columns]

# %%
#double checking the csv files which have separated protein types
df=pd.read_csv('SeparateProteinIDsClassic_no_grouping_no_remap_3000Files.csv')
print(df)
# Out:
#         Q-value Protein Type Protein Uniprot Protein Label
# 0      0.000441           sp          P35579    MYH9_HUMAN
# 1      0.000441           sp          Q15365   PCBP1_HUMAN
# 2      0.000441           sp          P04843    RPN1_HUMAN
# 3      0.000441           sp          P53618    COPB_HUMAN
# 4      0.000441           sp          P07737   PROF1_HUMAN
# ...         ...          ...             ...           ...
# 41247  0.950262      REV__sp        Q6ISS4-2   LAIR2_HUMAN
# 41248  0.950265      REV__sp        Q8N884-2    CGAS_HUMAN
# 41249  0.950265           sp        Q06330-3     SUH_HUMAN
# 41250  0.950267      REV__sp          P78417   GSTO1_HUMAN
# 41251  0.950267           sp        Q01433-3   AMPD2_HUMAN
#
# [41252 rows x 4 columns]

# %%
#double checking the csv files which have separated protein types
df=pd.read_csv('SeparateProteinIDsPicked_protein_group_no_remap_1900Files.csv')
print(df)
# Out:
#         Q-value Protein Type       Protein Uniprot  \
# 0      0.000146           sp                Q86UP2
# 1      0.000146           sp                Q9Y277
# 2      0.000146           sp                P35579
# 3      0.000146           sp                Q92835
# 4      0.000146           sp                P04843
# ...         ...          ...                   ...
# 26531  0.452872      REV__pI       c20riboseqorf35
# 26532  0.452872           sR  single_ribo513_HUMAN
# 26533  0.452872           sp                Q96SJ8
# 26534  0.452924      REV__sp                Q9BZA8
# 26535  0.452952      REV__sp              Q6ISS4-2
#
#                                            Protein Label
# 0      KTN1_HUMAN;sp|Q86UP2-2|KTN1_HUMAN;sp|Q86UP2-3|...
# 1                    VDAC3_HUMAN;sp|Q9Y277-2|VDAC3_HUMAN
# 2      MYH9_HUMAN;sp|A7E2Y1|MYH7B_HUMAN;sp|P11055|MYH...
# 3      SHIP1_HUMAN;sp|Q92835-2|SHIP1_HUMAN;sp|Q92835-...
# 4                                             RPN1_HUMAN
# ...

# %%
import pandas as pd
import os

# Create an empty dictionary to store the counts for each file
file_counts = {}

# Loop through all the CSV files in the directory
for filename in os.listdir():
    if filename.endswith('.csv'):
        # Read the CSV file into a DataFrame
        df = pd.read_csv(filename)
        
        # Split the protein type column into two columns
        df[['Protein Type', 'Protein Uniprot']] = df['Protein Type'].str.split('__', n=1, expand=True)

        # Count the number of target and decoy proteins
        target_count = df['Protein Type'].str.contains('REV').count() - df['Protein Type'].str.contains('REV').sum()
        decoy_count = df['Protein Type'].str.contains('REV').sum()

        # Add the counts to the dictionary
        file_counts[filename] = {'Target Proteins': target_count, 'Decoy Proteins': decoy_count}

# Create a DataFrame from the dictionary
results_df = pd.DataFrame.from_dict(file_counts, orient='index')

# Save the results to a CSV file
results_df.to_csv('ProteinCounts.csv')

# Print the results for each file
for filename, counts in file_counts.items():
    print(f'File: {filename}, Target Proteins: {counts["Target Proteins"]}, Decoy Proteins: {counts["Decoy Proteins"]}')
# Out:
# File: SeparateProteinIDsPicked_protein_group_no_remap_1900FIles.csv, Target Proteins: 17817, Decoy Proteins: 8719
# File: SeparateProteinIDsClassic_no_grouping_no_remap_800FIles.csv, Target Proteins: 12714, Decoy Proteins: 9929
# File: SeparateProteinIDsClassic_no_grouping_no_remap_500Files.csv, Target Proteins: 10387, Decoy Proteins: 7432
# File: SeparateProteinIDsClassic_no_grouping_no_remap_1300Files.csv, Target Proteins: 15317, Decoy Proteins: 13035
# File: SeparateProteinIDsPicked_protein_group_no_remap_1400Files.csv, Target Proteins: 16731, Decoy Proteins: 7501
# File: SeparateProteinIDsSavitski_no_remap_1000FIles.csv, Target Proteins: 12376, Decoy Proteins: 6182
# File: SeparateProteinIDsPicked_protein_group_no_remap_1100Files.csv, Target Proteins: 15996, Decoy Proteins: 6730
# File: SeparateProteinIDsPicked_protein_group_no_remap_800Files.csv, Target Proteins: 14838, Decoy Proteins: 6051
# ...

# %%
import pandas as pd
import os

# Define a list of filenames in the desired order
file_order = ['SeparateProteinIDsClassic_no_grouping_no_remap_100Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_200Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_300Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_400Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_500Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_600Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_700Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_800Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_900Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_1000Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_1100Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_1200Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_1300Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_1400Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_1500Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_1600Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_1700Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_1800Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_1900Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_2000Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_3000Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_4000Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_5000Files.csv', 
              'SeparateProteinIDsClassic_no_grouping_no_remap_6000Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_100Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_200Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_300Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_400Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_500Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_600Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_700Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_800Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_900Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_1000Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_1100Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_1200Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_1300Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_1400Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_1500Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_1600Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_1700Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_1800Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_1900Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_2000Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_3000Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_4000Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_5000Files.csv', 
              'SeparateProteinIDsSavitski_no_remap_6000Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_100Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_200Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_300Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_400Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_500Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_600Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_700Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_800Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_900Files.csv',
              'SeparateProteinIDsPicked_protein_group_no_remap_1000Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_1100Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_1200Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_1300Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_1400Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_1500Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_1600Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_1700Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_1800Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_1900Files.csv', 
              'SeparateProteinIDsPicked_protein_group_no_remap_2000Files.csv',
              'SeparateProteinIDsPicked_protein_group_no_remap_3000Files.csv',
              'SeparateProteinIDsPicked_protein_group_no_remap_4000Files.csv',
              'SeparateProteinIDsPicked_protein_group_no_remap_5000Files.csv',
              'SeparateProteinIDsPicked_protein_group_no_remap_6000Files.csv',

             ]

# Create an empty dictionary to store the counts for each file
file_counts = {}

# Loop through the filenames in the desired order
for filename in file_order:
    # Read the CSV file into a DataFrame
    df = pd.read_csv(filename)
        
    # Split the protein type column into two columns
    df[['Protein Type', 'Protein Uniprot']] = df['Protein Type'].str.split('__', n=1, expand=True)

    # Count the number of target and decoy proteins
    target_count = df['Protein Type'].str.contains('REV').count() - df['Protein Type'].str.contains('REV').sum()
    decoy_count = df['Protein Type'].str.contains('REV').sum()

    # Add the counts to the dictionary
    file_counts[filename] = {'Target Proteins': target_count, 'Decoy Proteins': decoy_count}

# Create a DataFrame from the dictionary
results_df = pd.DataFrame.from_dict(file_counts, orient='index')

# Save the results to a CSV file
results_df.to_csv('TargetsandDecoyProteinCountRawFiles.csv')

# Print the results for each file in the desired order
for filename in file_order:
    counts = file_counts[filename]
    print(f'File: {filename}, Target Proteins: {counts["Target Proteins"]}, Decoy Proteins: {counts["Decoy Proteins"]}')
# Out:
# File: SeparateProteinIDsClassic_no_grouping_no_remap_100Files.csv, Target Proteins: 4817, Decoy Proteins: 1439
# File: SeparateProteinIDsClassic_no_grouping_no_remap_200Files.csv, Target Proteins: 6054, Decoy Proteins: 2616
# File: SeparateProteinIDsClassic_no_grouping_no_remap_300Files.csv, Target Proteins: 7102, Decoy Proteins: 3901
# File: SeparateProteinIDsClassic_no_grouping_no_remap_400Files.csv, Target Proteins: 9015, Decoy Proteins: 6036
# File: SeparateProteinIDsClassic_no_grouping_no_remap_500Files.csv, Target Proteins: 10387, Decoy Proteins: 7432
# File: SeparateProteinIDsClassic_no_grouping_no_remap_600Files.csv, Target Proteins: 11330, Decoy Proteins: 8350
# File: SeparateProteinIDsClassic_no_grouping_no_remap_700Files.csv, Target Proteins: 12015, Decoy Proteins: 9104
# File: SeparateProteinIDsClassic_no_grouping_no_remap_800Files.csv, Target Proteins: 12714, Decoy Proteins: 9929
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data from the CSV file
df = pd.read_csv('TargetsandDecoyProteinCountRawFilesforPlot.csv')

# Create a figure and axis object
fig, ax = plt.subplots()

# Plot the target protein count as a line with blue color
ax.plot(df['Number of raw files'], df['Target Proteins'], color='blue', label='Target Proteins')

# Plot the decoy protein count as a line with red color
ax.plot(df['Number of raw files'], df['Decoy Proteins'], color='red', label='Decoy Proteins')

# Set the title, x-label, and y-label
ax.set_title('Number of Raw Files with Target and Decoy Proteins')
ax.set_xlabel('Number of Raw Files')
ax.set_ylabel('Protein Count')

# Add a legend to the plot
ax.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data from the CSV file
df = pd.read_csv('TargetsandDecoyProteinCountRawFilesforPlot.csv')

# Determine the method used in the CSV file based on the file name
if 'Classic_no_grouping_no_remap' in df.columns[0]:
    method = 'Classic, No Grouping, No Remap'
    target_color = 'blue'
    decoy_color = 'blue'
    decoy_linestyle = '--'
elif 'Savitski_no_remap' in df.columns[0]:
    method = 'Savitski, No Remap'
    target_color = 'red'
    decoy_color = 'red'
    decoy_linestyle = '--'
elif 'Picked_protein_group_no_remap' in df.columns[0]:
    method = 'Picked Protein Group, No Remap'
    target_color = 'green'
    decoy_color = 'green'
    decoy_linestyle = '--'
else:
    method = 'Unknown Method'
    target_color = 'blue'
    decoy_color = 'red'
    decoy_linestyle = '--'

# Create a figure and axis object
fig, ax = plt.subplots()

# Plot the target protein count as a line with the specified color
ax.plot(df['Number of raw files'], df['Target Proteins'], color=target_color, label='Target Proteins')

# Plot the decoy protein count as a dotted line with the specified color
ax.plot(df['Number of raw files'], df['Decoy Proteins'], color=decoy_color, linestyle=decoy_linestyle, label='Decoy Proteins')

# Set the title, x-label, and y-label
ax.set_title(f'Number of Raw Files with Target and Decoy Proteins ({method})')
ax.set_xlabel('Number of Raw Files')
ax.set_ylabel('Protein Count (x1000)')

# Set the y-tick labels to display in thousands
ax.set_yticklabels(['{:.0f}k'.format(y/1000) for y in ax.get_yticks()])

# Add a legend to the plot
ax.legend()

# Show the plot
plt.show()
# Out:
# /var/folders/bt/n98c3tq15s3d6866b0l_z_400000gn/T/ipykernel_17012/861526706.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:.0f}k'.format(y/1000) for y in ax.get_yticks()])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data from the CSV file
df = pd.read_csv('TargetsandDecoyProteinCountClassic_no_grouping_no_remap.csv')

# Create a figure and axis object
fig, ax = plt.subplots()

# Plot the target protein count as a line with blue color
ax.plot(df['Number of raw files'], df['Target Proteins'], color='blue', label='Target Proteins')

# Plot the decoy protein count as a line with red color
ax.plot(df['Number of raw files'], df['Decoy Proteins'], color='red', label='Decoy Proteins')

# Set the title, x-label, and y-label
ax.set_title('Number of Raw Files with Target and Decoy Proteins')
ax.set_xlabel('Number of Raw Files')
ax.set_ylabel('Protein Count')

# Add a legend to the plot
ax.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('TargetsandDecoyProteinCountRawFilesforPlotA.csv')
print(df)
# Out:
#                       Method and Number of Raw files   \
# 0   SeparateProteinIDsClassic_no_grouping_no_remap...
# 1   SeparateProteinIDsClassic_no_grouping_no_remap...
# 2   SeparateProteinIDsClassic_no_grouping_no_remap...
# 3   SeparateProteinIDsClassic_no_grouping_no_remap...
# 4   SeparateProteinIDsClassic_no_grouping_no_remap...
# 5   SeparateProteinIDsClassic_no_grouping_no_remap...
# 6   SeparateProteinIDsClassic_no_grouping_no_remap...
# 7   SeparateProteinIDsClassic_no_grouping_no_remap...
# 8   SeparateProteinIDsClassic_no_grouping_no_remap...
# 9   SeparateProteinIDsClassic_no_grouping_no_remap...
# 10  SeparateProteinIDsClassic_no_grouping_no_remap...
# 11  SeparateProteinIDsClassic_no_grouping_no_remap...
# 12  SeparateProteinIDsClassic_no_grouping_no_remap...
# 13  SeparateProteinIDsClassic_no_grouping_no_remap...
# 14  SeparateProteinIDsClassic_no_grouping_no_remap...
# 15  SeparateProteinIDsClassic_no_grouping_no_remap...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a pandas dataframe
df = pd.read_csv('TargetsandDecoyProteinCountRawFilesforPlotA.csv')

# Group the dataframe by method
grouped = df.groupby('Method')

# Set the colors for the different methods
colors = {'Classic_no_grouping_no_remap': 'blue', 'Savitski_no_remap': 'red', 'Picked_protein_group_no_remap': 'green'}

# Create a figure and axis
fig, ax = plt.subplots()

# Loop through the grouped data and plot a line for each method
for name, group in grouped:
    ax.plot(group['Number of raw files'], group['Target Proteins'], color=colors[name], label=name+' Target')
    ax.plot(group['Number of raw files'], group['Decoy Proteins'], linestyle='dashed', color=colors[name], label=name+' Decoy')

# Set the axis labels and legend
ax.set_xlabel('Number of raw files')
ax.set_ylabel('Number of proteins')
ax.legend(loc='upper left', bbox_to_anchor=(1.05, 1))

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a pandas dataframe
df = pd.read_csv('/Users/anabelyong/miniconda3/lib/python3.10/site-packages/jupyterlab/Subset750RawfilesCut/TargetandDecoyProteinCounts6000Files/TargetsandDecoyProteinCountRawFilesforPlotC.csv')

# Group the dataframe by method
grouped = df.groupby('Method')

# Set the colors for the different methods
colors = {'Classic_no_grouping_no_remap': 'blue', 'Savitski_no_remap': 'red', 'Picked_protein_group_no_remap': 'green', '1% FDR': 'black'}

# Create a figure and axis
fig, ax = plt.subplots()

# Loop through the grouped data and plot a line for each method
for name, group in grouped:
    #ax.plot(group['Number of raw files'], group['Target Proteins'], color=colors[name], label=name+' Target')
    #ax.plot(group['Number of raw files'], group['Decoy Proteins'], linestyle='dashed', color=colors[name], label=name+' Decoy')
    ax.plot(group['Number of raw files'], group['0.01FDRDecoys'], linestyle='dashed', color=colors[name], label=name+' Decoy at 1% FDR')
    #ax.plot(group['Number of raw files'], group['0.01FDRTargets'], color=colors[name], label=name+' Targets at 1% FDR')

# Set the axis labels and legend
ax.set_xlabel('Number of raw files')
ax.set_ylabel('Number of proteins')
ax.legend(loc='upper left', bbox_to_anchor=(1.05, 1))

# Show the plot
plt.show()

# %%
# Load the CSV file into a pandas DataFrame
df = pd.read_csv('SeparateProteinIDsClassic_no_grouping_no_remap_4000Files.csv')

# Count the number of occurrences of each unique string in the 'Column 1' column
value_counts = df['Protein Type'].value_counts()

# Print the value counts
print(value_counts)

# Plot the value counts as a bar chart
value_counts.plot(kind='bar')
plt.title('classic_no_grouping_no_remap_100 Results')
plt.xlabel('Type of Protein')
plt.ylabel('count')
plt.show()
# Out:
# sp         18953
# REV__sp    18202
# REV__sR     1763
# sR          1697
# REV__pI     1340
# pI          1315
# sU           203
# REV__sU      178
# nC           118
# REV__nC       95
# Name: Protein Type, dtype: int64

# %%
df = pd.read_csv('SeparateProteinIDsClassic_no_grouping_no_remap_6000Files.csv')

# filter for Q-value < 0.01
df_filtered = df[df['Q-value'] < 0.01]

# group by protein type and count the number of each type
protein_count = df_filtered.groupby('Protein Type')['Protein Type'].count()

# print the protein count
print(protein_count)

# Plot the value counts as a bar chart
protein_count.plot(kind='bar')
plt.title('classic_no_grouping_no_remap_100 Q-value <0.01 Filter Results')
plt.xlabel('Type of Protein')
plt.ylabel('count')
# add labels to the bars
for i, count in enumerate(protein_count):
    plt.text(i, count + 50, str(count), ha='center', va='bottom')

plt.show()
# Out:
# Protein Type
# REV__pI       1
# REV__sR       3
# REV__sp      63
# nC            1
# pI            1
# sR            2
# sp         6821
# Name: Protein Type, dtype: int64
